# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/ProstrateX2/Code/Preprocessing
# Out:
# /content/drive/My Drive/ProstrateX2/Code/Preprocessing

# %%
ls
# Out:
# 01_generate_directories.py  03_resample_nifti.py     05_patch_extraction.py
# 02_convert_to_nifti.py      04_compile_meta_data.py  06_generate_numpy.py

# %%
# !python 01_generate_directories.py
# Out:
# Generate directory structure for which type of data (1-Train; 2-Test):1
# 1
# Done creating directory structure...

# %%
# !python 02_convert_to_nifti.py
# Out:
# What type of data to convert? (1-Train; 2-Test):1
# 1
# Done generating paths to dicom files for conversion...
#
# Generating nifti files from dicom...
#
# Successful dicom to nifti conversion of: ProstateX-0199 1
# Successful dicom to nifti conversion of: ProstateX-0203 2
# Successful dicom to nifti conversion of: ProstateX-0200 3
# Successful dicom to nifti conversion of: ProstateX-0198 4
# Successful dicom to nifti conversion of: ProstateX-0201 5
# Successful dicom to nifti conversion of: ProstateX-0197 6
# Successful dicom to nifti conversion of: ProstateX-0202 7
# Successful dicom to nifti conversion of: ProstateX-0196 8
# Successful dicom to nifti conversion of: ProstateX-0195 9
# Successful dicom to nifti conversion of: ProstateX-0194 10
# Successful dicom to nifti conversion of: ProstateX-0192 11
# Successful dicom to nifti conversion of: ProstateX-0190 12
# Successful dicom to nifti conversion of: ProstateX-0193 13
# ...

# %%
# !python 03_resample_nifti.py
# Out:
# Which dataset is being resampled? (1-Train; 2-Test):1
#
#
# Resampling: generated/nifti/ProstateX-0199/t2/4_t2_tse_tra.nii.gz
# original spacing: (0.5625, 0.5625, 3.0)
# desired spacing: (0.5, 0.5, 3.0)
# resampled spacing: (0.5, 0.5, 3.0)
# original size: (320, 320, 19)
# resampled size: (360, 360, 19)
#
#
# Saving image to: generated/nifti_resampled/ProstateX-0199/t2/4_t2_tse_tra.nii.gz
#
#
# Resampling: generated/nifti/ProstateX-0199/bval/9_diffusie-3scan-4bval_fscalc_bval.nii.gz
# original spacing: (2.0, 2.0, 4.0)
# desired spacing: (2.0, 2.0, 3.0)
# resampled spacing: (2.0, 2.0, 3.0)
# original size: (128, 106, 20)
# resampled size: (128, 106, 27)
#
#
# Saving image to: generated/nifti_resampled/ProstateX-0199/bval/9_diffusie-3scan-4bval_fscalc_bval.nii.gz
#
#
# Resampling: generated/nifti/ProstateX-0199/adc/8_diffusie-3scan-4bval_fs_adc.nii.gz
# original spacing: (2.0, 2.0, 4.0)
# desired spacing: (2.0, 2.0, 3.0)
# resampled spacing: (2.0, 2.0, 3.0)
# ...

# %%
# !python 04_compile_meta_data.py
# Out:
# Which dataset are you working with? (1-Train; 2-Test):1

# %%
# !python 05_patch_extraction.py
# Out:
# Which dataset are you working with? (1-Train; 2-Test):1
# 1
# Problem with image: ProstateX-0105 /content/drive/My Drive/ProstrateX2/Dataset/Training/generated/nifti_resampled/ProstateX-0105/ktrans/ProstateX-0105-ktrans.nii.gz
# Problem with image: ProstateX-0105 /content/drive/My Drive/ProstrateX2/Dataset/Training/generated/nifti_resampled/ProstateX-0105/ktrans/ProstateX-0105-ktrans.nii.gz

# %%
# !python 06_generate_numpy.py
# Out:
# Which dataset are you working with? (1-Train; 2-Test):1
